# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 598

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url="http://api.openweathermap.org/data/2.5/weather?"
#units=Imperial&APPID=58cdd1ed9f533a78e558533f70a2c05a&q=

unit="imperial"
query_url=f"{url}units={unit}&APPID={api_key}&q="

# %%
city_list=[]         
cloudiness=[]    
country=[]      
date=[]          
humidity=[]     
lat=[]        
lng=[]          
max_temp=[]      
wind_speed=[]
record=1
set=1
print('Beginning Data Retrieval\n-------------------------------')
for city in cities:
    try:
        response=requests.get(query_url+city).json()
        city_list.append(response['name'])
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response['wind']['speed'])
        print(f'Processing Record {record} of Set {set}| {city}')
        record+=1
        if record>=51:
            record=1
            set+=1
    except:
        print("City not found. Skipping ...")
        
print("-----------------------------\n Data Retreival Complete\n-----------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of Set 1| hilo
# Processing Record 2 of Set 1| port elizabeth
# Processing Record 3 of Set 1| ribeira grande
# Processing Record 4 of Set 1| aklavik
# Processing Record 5 of Set 1| porto novo
# Processing Record 6 of Set 1| rio gallegos
# Processing Record 7 of Set 1| mapiri
# Processing Record 8 of Set 1| vaini
# Processing Record 9 of Set 1| qaanaaq
# Processing Record 10 of Set 1| hithadhoo
# Processing Record 11 of Set 1| rikitea
# Processing Record 12 of Set 1| east london
# Processing Record 13 of Set 1| busselton
# Processing Record 14 of Set 1| kaitangata
# Processing Record 15 of Set 1| mataura
# Processing Record 16 of Set 1| sandur
# Processing Record 17 of Set 1| nhulunbuy
# Processing Record 18 of Set 1| provideniya
# Processing Record 19 of Set 1| manono
# Processing Record 20 of Set 1| cape town
# Processing Record 21 of Set 1| luderitz
# Processing Record 22 of Set 1| fairbanks
# Processing Record 23 of Set 1| casablanca
# Processing Record 24 of Set 1| chernyshevskiy
# Processing Record 25 of Set 1| magadi
# Processing Record 26 of Set 1| khatanga
# Processing Record 27 of Set 1| nicoya
# Processing Record 28 of Set 1| arraial do cabo
# Processing Record 29 of Set 1| baykit
# Processing Record 30 of Set 1| chokurdakh
# Processing Record 31 of Set 1| puerto ayora
# Processing Record 32 of Set 1| yellowknife
# Processing Record 33 of Set 1| grindavik
# Processing Record 34 of Set 1| jacareacanga
# Processing Record 35 of Set 1| umea
# Processing Record 36 of Set 1| san cristobal
# Processing Record 37 of Set 1| port-cartier
# Processing Record 38 of Set 1| bredasdorp
# Processing Record 39 of Set 1| port alfred
# Processing Record 40 of Set 1| avarua
# Processing Record 41 of Set 1| ushuaia
# Processing Record 42 of Set 1| vila franca do campo
# Processing Record 43 of Set 1| butaritari
# Processing Record 44 of Set 1| punta arenas
# Processing Record 45 of Set 1| noumea
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 46 of Set 1| pucallpa
# Processing Record 47 of Set 1| kapaa
# Processing Record 48 of Set 1| dikson
# Processing Record 49 of Set 1| rialma
# Processing Record 50 of Set 1| uvat
# Processing Record 1 of Set 2| honiara
# Processing Record 2 of Set 2| yulara
# Processing Record 3 of Set 2| evensk
# Processing Record 4 of Set 2| phan thiet
# Processing Record 5 of Set 2| am timan
# Processing Record 6 of Set 2| torbay
# Processing Record 7 of Set 2| jamestown
# City not found. Skipping ...
# Processing Record 8 of Set 2| bluff
# Processing Record 9 of Set 2| parana
# Processing Record 10 of Set 2| mildura
# Processing Record 11 of Set 2| ormara
# Processing Record 12 of Set 2| atuona
# Processing Record 13 of Set 2| ponta do sol
# Processing Record 14 of Set 2| mahebourg
# Processing Record 15 of Set 2| ponta delgada
# Processing Record 16 of Set 2| new norfolk
# City not found. Skipping ...
# Processing Record 17 of Set 2| juegang
# Processing Record 18 of Set 2| souillac
# Processing Record 19 of Set 2| tocopilla
# Processing Record 20 of Set 2| boa vista
# Processing Record 21 of Set 2| saskylakh
# Processing Record 22 of Set 2| bengkulu
# Processing Record 23 of Set 2| nikolskoye
# Processing Record 24 of Set 2| caravelas
# Processing Record 25 of Set 2| chuy
# Processing Record 26 of Set 2| kasongo-lunda
# Processing Record 27 of Set 2| praia
# Processing Record 28 of Set 2| albany
# Processing Record 29 of Set 2| ullal
# Processing Record 30 of Set 2| mar del plata
# Processing Record 31 of Set 2| turbat
# Processing Record 32 of Set 2| port hardy
# Processing Record 33 of Set 2| esperance
# City not found. Skipping ...
# Processing Record 34 of Set 2| paranagua
# Processing Record 35 of Set 2| lebu
# Processing Record 36 of Set 2| eregli
# Processing Record 37 of Set 2| riyadh
# Processing Record 38 of Set 2| bethel
# City not found. Skipping ...
# Processing Record 39 of Set 2| anloga
# Processing Record 40 of Set 2| hervey bay
# Processing Record 41 of Set 2| sambava
# City not found. Skipping ...
# Processing Record 42 of Set 2| tirumullaivasal
# Processing Record 43 of Set 2| kenai
# Processing Record 44 of Set 2| castro
# Processing Record 45 of Set 2| athabasca
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 46 of Set 2| tuatapere
# Processing Record 47 of Set 2| alofi
# Processing Record 48 of Set 2| yarensk
# Processing Record 49 of Set 2| havoysund
# Processing Record 50 of Set 2| thinadhoo
# City not found. Skipping ...
# Processing Record 1 of Set 3| benguela
# Processing Record 2 of Set 3| hamilton
# Processing Record 3 of Set 3| jeremie
# Processing Record 4 of Set 3| mitu
# Processing Record 5 of Set 3| nioro
# Processing Record 6 of Set 3| geraldton
# City not found. Skipping ...
# Processing Record 7 of Set 3| la ronge
# Processing Record 8 of Set 3| kwinana
# Processing Record 9 of Set 3| ambon
# Processing Record 10 of Set 3| clyde river
# Processing Record 11 of Set 3| san patricio
# Processing Record 12 of Set 3| lepa
# Processing Record 13 of Set 3| tomatlan
# Processing Record 14 of Set 3| hermanus
# Processing Record 15 of Set 3| komsomolskiy
# Processing Record 16 of Set 3| yanam
# Processing Record 17 of Set 3| ozerne
# Processing Record 18 of Set 3| thanh hoa
# Processing Record 19 of Set 3| emba
# Processing Record 20 of Set 3| xinyu
# Processing Record 21 of Set 3| hobart
# Processing Record 22 of Set 3| sitka
# Processing Record 23 of Set 3| rosarito
# Processing Record 24 of Set 3| emerald
# Processing Record 25 of Set 3| cherskiy
# Processing Record 26 of Set 3| cidreira
# Processing Record 27 of Set 3| tasiilaq
# Processing Record 28 of Set 3| guerrero negro
# Processing Record 29 of Set 3| lazaro cardenas
# Processing Record 30 of Set 3| saint-francois
# Processing Record 31 of Set 3| cachoeirinha
# Processing Record 32 of Set 3| constitucion
# Processing Record 33 of Set 3| kayes
# Processing Record 34 of Set 3| portree
# Processing Record 35 of Set 3| paratinga
# Processing Record 36 of Set 3| mulanje
# Processing Record 37 of Set 3| beira
# Processing Record 38 of Set 3| pindwara
# Processing Record 39 of Set 3| maarianhamina
# Processing Record 40 of Set 3| dingle
# Processing Record 41 of Set 3| marawi
# Processing Record 42 of Set 3| salalah
# Processing Record 43 of Set 3| trat
# Processing Record 44 of Set 3| goderich
# Processing Record 45 of Set 3| adrar
# Processing Record 46 of Set 3| lagoa
# Processing Record 47 of Set 3| nome
# Processing Record 48 of Set 3| oistins
# Processing Record 49 of Set 3| kodiak
# Processing Record 50 of Set 3| asosa
# Processing Record 1 of Set 4| casa nova
# Processing Record 2 of Set 4| klaksvik
# Processing Record 3 of Set 4| bang saphan
# Processing Record 4 of Set 4| thompson
# Processing Record 5 of Set 4| port-gentil
# Processing Record 6 of Set 4| kourou
# Processing Record 7 of Set 4| los llanos de aridane
# City not found. Skipping ...
# Processing Record 8 of Set 4| dzaoudzi
# Processing Record 9 of Set 4| flinders
# Processing Record 10 of Set 4| guozhen
# Processing Record 11 of Set 4| maues
# Processing Record 12 of Set 4| yar-sale
# Processing Record 13 of Set 4| saint-philippe
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 14 of Set 4| mehamn
# Processing Record 15 of Set 4| susehri
# Processing Record 16 of Set 4| sola
# Processing Record 17 of Set 4| omsukchan
# Processing Record 18 of Set 4| georgetown
# Processing Record 19 of Set 4| chara
# City not found. Skipping ...
# Processing Record 20 of Set 4| barrow
# Processing Record 21 of Set 4| pisco
# Processing Record 22 of Set 4| isangel
# City not found. Skipping ...
# Processing Record 23 of Set 4| faya
# Processing Record 24 of Set 4| faanui
# Processing Record 25 of Set 4| pevek
# City not found. Skipping ...
# Processing Record 26 of Set 4| meulaboh
# Processing Record 27 of Set 4| simbahan
# Processing Record 28 of Set 4| iqaluit
# Processing Record 29 of Set 4| port lincoln
# Processing Record 30 of Set 4| shache
# Processing Record 31 of Set 4| zhelyabovka
# Processing Record 32 of Set 4| severo-kurilsk
# City not found. Skipping ...
# Processing Record 33 of Set 4| nueva germania
# Processing Record 34 of Set 4| buta
# Processing Record 35 of Set 4| palang
# Processing Record 36 of Set 4| port macquarie
# Processing Record 37 of Set 4| qaqortoq
# Processing Record 38 of Set 4| kruisfontein
# Processing Record 39 of Set 4| impfondo
# Processing Record 40 of Set 4| sioux lookout
# Processing Record 41 of Set 4| narsaq
# Processing Record 42 of Set 4| asau
# Processing Record 43 of Set 4| nanortalik
# Processing Record 44 of Set 4| airai
# Processing Record 45 of Set 4| ahipara
# Processing Record 46 of Set 4| siocon
# Processing Record 47 of Set 4| mettet
# Processing Record 48 of Set 4| contamana
# Processing Record 49 of Set 4| uray
# Processing Record 50 of Set 4| francistown
# Processing Record 1 of Set 5| nago
# Processing Record 2 of Set 5| morristown
# Processing Record 3 of Set 5| maragogi
# Processing Record 4 of Set 5| chicama
# Processing Record 5 of Set 5| ribeira brava
# Processing Record 6 of Set 5| vostok
# Processing Record 7 of Set 5| ilulissat
# Processing Record 8 of Set 5| khrebtovaya
# Processing Record 9 of Set 5| erenhot
# Processing Record 10 of Set 5| kloulklubed
# Processing Record 11 of Set 5| pangnirtung
# Processing Record 12 of Set 5| arecibo
# Processing Record 13 of Set 5| te anau
# Processing Record 14 of Set 5| kashan
# Processing Record 15 of Set 5| puerto ayacucho
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 16 of Set 5| kavieng
# Processing Record 17 of Set 5| addanki
# Processing Record 18 of Set 5| pokosnoye
# Processing Record 19 of Set 5| zhigansk
# Processing Record 20 of Set 5| puerto gaitan
# Processing Record 21 of Set 5| bulawayo
# Processing Record 22 of Set 5| manzanillo
# Processing Record 23 of Set 5| policoro
# Processing Record 24 of Set 5| bambous virieux
# Processing Record 25 of Set 5| port keats
# Processing Record 26 of Set 5| mungeli
# Processing Record 27 of Set 5| birin
# Processing Record 28 of Set 5| ryotsu
# Processing Record 29 of Set 5| talnakh
# Processing Record 30 of Set 5| godda
# Processing Record 31 of Set 5| lensk
# Processing Record 32 of Set 5| tiksi
# Processing Record 33 of Set 5| betamcherla
# Processing Record 34 of Set 5| lebowakgomo
# Processing Record 35 of Set 5| olafsvik
# Processing Record 36 of Set 5| yenagoa
# City not found. Skipping ...
# Processing Record 37 of Set 5| talcahuano
# Processing Record 38 of Set 5| luanda
# Processing Record 39 of Set 5| richards bay
# Processing Record 40 of Set 5| haines junction
# Processing Record 41 of Set 5| norsup
# Processing Record 42 of Set 5| ghanzi
# Processing Record 43 of Set 5| carnarvon
# Processing Record 44 of Set 5| rognan
# Processing Record 45 of Set 5| udachnyy
# Processing Record 46 of Set 5| adre
# Processing Record 47 of Set 5| tabou
# Processing Record 48 of Set 5| tuktoyaktuk
# Processing Record 49 of Set 5| alta floresta
# Processing Record 50 of Set 5| champerico
# Processing Record 1 of Set 6| abu samrah
# Processing Record 2 of Set 6| codrington
# Processing Record 3 of Set 6| de-kastri
# Processing Record 4 of Set 6| sao jose da coroa grande
# Processing Record 5 of Set 6| auki
# Processing Record 6 of Set 6| spantov
# Processing Record 7 of Set 6| kaili
# Processing Record 8 of Set 6| poplar bluff
# Processing Record 9 of Set 6| kuusamo
# Processing Record 10 of Set 6| rio brilhante
# Processing Record 11 of Set 6| kurilsk
# Processing Record 12 of Set 6| inhambane
# Processing Record 13 of Set 6| itarema
# Processing Record 14 of Set 6| santa luzia
# Processing Record 15 of Set 6| manitouwadge
# Processing Record 16 of Set 6| wuwei
# Processing Record 17 of Set 6| makakilo city
# Processing Record 18 of Set 6| santa lucia
# Processing Record 19 of Set 6| north battleford
# Processing Record 20 of Set 6| russell
# Processing Record 21 of Set 6| padang
# Processing Record 22 of Set 6| mnogovershinnyy
# Processing Record 23 of Set 6| le moule
# Processing Record 24 of Set 6| shimoda
# Processing Record 25 of Set 6| orcopampa
# Processing Record 26 of Set 6| kahului
# Processing Record 27 of Set 6| jiexiu
# Processing Record 28 of Set 6| nishihara
# City not found. Skipping ...
# Processing Record 29 of Set 6| whitehorse
# Processing Record 30 of Set 6| campana
# Processing Record 31 of Set 6| necochea
# Processing Record 32 of Set 6| upernavik
# Processing Record 33 of Set 6| rawson
# Processing Record 34 of Set 6| siaya
# Processing Record 35 of Set 6| itoman
# Processing Record 36 of Set 6| changanacheri
# Processing Record 37 of Set 6| ostrovnoy
# Processing Record 38 of Set 6| oktyabrskiy
# Processing Record 39 of Set 6| cabra
# Processing Record 40 of Set 6| najran
# Processing Record 41 of Set 6| cairns
# Processing Record 42 of Set 6| isla aguada
# Processing Record 43 of Set 6| herat
# Processing Record 44 of Set 6| tongchuan
# Processing Record 45 of Set 6| natitingou
# Processing Record 46 of Set 6| sao felipe
# Processing Record 47 of Set 6| victoria
# Processing Record 48 of Set 6| aktyubinskiy
# City not found. Skipping ...
# Processing Record 49 of Set 6| guaratuba
# Processing Record 50 of Set 6| alyangula
# City not found. Skipping ...
# Processing Record 1 of Set 7| eureka
# Processing Record 2 of Set 7| lorengau
# Processing Record 3 of Set 7| yashkul
# Processing Record 4 of Set 7| leningradskiy
# Processing Record 5 of Set 7| puerto baquerizo moreno
# Processing Record 6 of Set 7| batticaloa
# Processing Record 7 of Set 7| inirida
# Processing Record 8 of Set 7| aykhal
# Processing Record 9 of Set 7| tual
# Processing Record 10 of Set 7| mercedes
# Processing Record 11 of Set 7| cradock
# Processing Record 12 of Set 7| pemangkat
# Processing Record 13 of Set 7| kodinsk
# Processing Record 14 of Set 7| ludwigslust
# Processing Record 15 of Set 7| rehoboth
# Processing Record 16 of Set 7| lompoc
# Processing Record 17 of Set 7| troitsko-pechorsk
# Processing Record 18 of Set 7| banmankhi
# Processing Record 19 of Set 7| hernani
# Processing Record 20 of Set 7| waingapu
# Processing Record 21 of Set 7| baruun-urt
# Processing Record 22 of Set 7| olinda
# Processing Record 23 of Set 7| oksfjord
# Processing Record 24 of Set 7| bandarbeyla
# Processing Record 25 of Set 7| sisimiut
# Processing Record 26 of Set 7| quatre cocos
# Processing Record 27 of Set 7| galveston
# Processing Record 28 of Set 7| kaihua
# Processing Record 29 of Set 7| makarov
# Processing Record 30 of Set 7| laje
# Processing Record 31 of Set 7| yagodnoye
# Processing Record 32 of Set 7| wuchang
# City not found. Skipping ...
# Processing Record 33 of Set 7| sawakin
# Processing Record 34 of Set 7| palasa
# Processing Record 35 of Set 7| na klang
# City not found. Skipping ...
# Processing Record 36 of Set 7| urusha
# Processing Record 37 of Set 7| mount gambier
# Processing Record 38 of Set 7| gamba
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 39 of Set 7| sakakah
# Processing Record 40 of Set 7| bubaque
# Processing Record 41 of Set 7| hammerfest
# Processing Record 42 of Set 7| miyakonojo
# Processing Record 43 of Set 7| longyearbyen
# Processing Record 44 of Set 7| khuzhir
# Processing Record 45 of Set 7| huehuetenango
# Processing Record 46 of Set 7| faranah
# Processing Record 47 of Set 7| spornoye
# Processing Record 48 of Set 7| hobyo
# Processing Record 49 of Set 7| salinas
# Processing Record 50 of Set 7| cabo san lucas
# Processing Record 1 of Set 8| rudnichnyy
# Processing Record 2 of Set 8| miraflores
# Processing Record 3 of Set 8| porto velho
# Processing Record 4 of Set 8| santa rosa
# Processing Record 5 of Set 8| tokur
# Processing Record 6 of Set 8| praia da vitoria
# Processing Record 7 of Set 8| vanavara
# Processing Record 8 of Set 8| mizan teferi
# Processing Record 9 of Set 8| rundu
# Processing Record 10 of Set 8| morondava
# City not found. Skipping ...
# Processing Record 11 of Set 8| guhagar
# Processing Record 12 of Set 8| campbell river
# City not found. Skipping ...
# Processing Record 13 of Set 8| bauchi
# City not found. Skipping ...
# Processing Record 14 of Set 8| huanan
# Processing Record 15 of Set 8| uglegorsk
# Processing Record 16 of Set 8| tucuman
# Processing Record 17 of Set 8| carupano
# Processing Record 18 of Set 8| shubarshi
# Processing Record 19 of Set 8| songkhla
# Processing Record 20 of Set 8| ucluelet
# Processing Record 21 of Set 8| tigil
# Processing Record 22 of Set 8| anchorage
# Processing Record 23 of Set 8| sinnamary
# Processing Record 24 of Set 8| mizdah
# Processing Record 25 of Set 8| kitimat
# Processing Record 26 of Set 8| grand gaube
# Processing Record 27 of Set 8| araouane
# Processing Record 28 of Set 8| khash
# Processing Record 29 of Set 8| mogadishu
# Processing Record 30 of Set 8| hofn
# Processing Record 31 of Set 8| santa maria
# Processing Record 32 of Set 8| nakamura
# Processing Record 33 of Set 8| cortez
# Processing Record 34 of Set 8| divnomorskoye
# Processing Record 35 of Set 8| saint george
# Processing Record 36 of Set 8| portland
# Processing Record 37 of Set 8| katsuura
# Processing Record 38 of Set 8| bensonville
# Processing Record 39 of Set 8| krasnoselkup
# Processing Record 40 of Set 8| hami
# Processing Record 41 of Set 8| saint-joseph
# Processing Record 42 of Set 8| homa bay
# Processing Record 43 of Set 8| preobrazheniye
# Processing Record 44 of Set 8| igarka
# Processing Record 45 of Set 8| pemberton
# City not found. Skipping ...
# Processing Record 46 of Set 8| norman wells
# Processing Record 47 of Set 8| saint-raymond
# Processing Record 48 of Set 8| oberstdorf
# Processing Record 49 of Set 8| gallup
# Processing Record 50 of Set 8| half moon bay
# Processing Record 1 of Set 9| sao luiz gonzaga
# Processing Record 2 of Set 9| aksu
# Processing Record 3 of Set 9| tevaitoa
# Processing Record 4 of Set 9| pinheiro
# Processing Record 5 of Set 9| karoi
# Processing Record 6 of Set 9| berezovyy
# Processing Record 7 of Set 9| gorzow wielkopolski
# City not found. Skipping ...
# Processing Record 8 of Set 9| churapcha
# Processing Record 9 of Set 9| ancud
# Processing Record 10 of Set 9| sobolevo
# Processing Record 11 of Set 9| sao joao da barra
# Processing Record 12 of Set 9| alice springs
# Processing Record 13 of Set 9| seoul
# Processing Record 14 of Set 9| khuzdar
# Processing Record 15 of Set 9| grand-santi
# Processing Record 16 of Set 9| basco
# Processing Record 17 of Set 9| mocuba
# Processing Record 18 of Set 9| dargaville
# Processing Record 19 of Set 9| sao filipe
# Processing Record 20 of Set 9| henties bay
# Processing Record 21 of Set 9| biak
# City not found. Skipping ...
# Processing Record 22 of Set 9| ginda
# Processing Record 23 of Set 9| pacific grove
# Processing Record 24 of Set 9| metro
# Processing Record 25 of Set 9| bogacs
# Processing Record 26 of Set 9| popondetta
# Processing Record 27 of Set 9| temuco
# Processing Record 28 of Set 9| karratha
# Processing Record 29 of Set 9| sept-iles
# Processing Record 30 of Set 9| bud
# City not found. Skipping ...
# Processing Record 31 of Set 9| sidney
# Processing Record 32 of Set 9| avera
# Processing Record 33 of Set 9| taiyuan
# Processing Record 34 of Set 9| mataram
# Processing Record 35 of Set 9| raudeberg
# Processing Record 36 of Set 9| petrokamenskoye
# Processing Record 37 of Set 9| ambilobe
# Processing Record 38 of Set 9| peruibe
# Processing Record 39 of Set 9| almaznyy
# Processing Record 40 of Set 9| kholbon
# Processing Record 41 of Set 9| tazovskiy
# Processing Record 42 of Set 9| sanming
# Processing Record 43 of Set 9| san ciro de acosta
# Processing Record 44 of Set 9| poum
# Processing Record 45 of Set 9| north bend
# Processing Record 46 of Set 9| darhan
# Processing Record 47 of Set 9| atar
# Processing Record 48 of Set 9| nehe
# Processing Record 49 of Set 9| mudgee
# Processing Record 50 of Set 9| sulangan
# Processing Record 1 of Set 10| denia
# Processing Record 2 of Set 10| niagara falls
# Processing Record 3 of Set 10| toora-khem
# Processing Record 4 of Set 10| hearst
# Processing Record 5 of Set 10| atasu
# Processing Record 6 of Set 10| gelemso
# City not found. Skipping ...
# Processing Record 7 of Set 10| nordhausen
# Processing Record 8 of Set 10| columbia
# Processing Record 9 of Set 10| storforshei
# Processing Record 10 of Set 10| abu dhabi
# City not found. Skipping ...
# Processing Record 11 of Set 10| sharanga
# Processing Record 12 of Set 10| tatawin
# Processing Record 13 of Set 10| saint-pierre
# Processing Record 14 of Set 10| enshi
# Processing Record 15 of Set 10| caraquet
# Processing Record 16 of Set 10| tura
# Processing Record 17 of Set 10| hartselle
# Processing Record 18 of Set 10| rio grande
# Processing Record 19 of Set 10| camacha
# Processing Record 20 of Set 10| beringovskiy
# Processing Record 21 of Set 10| concepcion
# Processing Record 22 of Set 10| collierville
# Processing Record 23 of Set 10| purpe
# City not found. Skipping ...
# Processing Record 24 of Set 10| tandalti
# Processing Record 25 of Set 10| jhelum
# Processing Record 26 of Set 10| hambantota
# Processing Record 27 of Set 10| coquimbo
# Processing Record 28 of Set 10| pravda
# Processing Record 29 of Set 10| surgut
# Processing Record 30 of Set 10| ninh binh
# City not found. Skipping ...
# Processing Record 31 of Set 10| monte santo
# Processing Record 32 of Set 10| caconda
# Processing Record 33 of Set 10| havelock
# Processing Record 34 of Set 10| sechura
# Processing Record 35 of Set 10| sao joao da boa vista
# Processing Record 36 of Set 10| moron
# Processing Record 37 of Set 10| tamandare
# Processing Record 38 of Set 10| vestmannaeyjar
# Processing Record 39 of Set 10| saldanha
# Processing Record 40 of Set 10| senno
# Processing Record 41 of Set 10| northam
# Processing Record 42 of Set 10| bolshaya rechka
# Processing Record 43 of Set 10| umm kaddadah
# Processing Record 44 of Set 10| nerchinskiy zavod
# Processing Record 45 of Set 10| rantepao
# Processing Record 46 of Set 10| touros
# Processing Record 47 of Set 10| shenzhen
# Processing Record 48 of Set 10| bairiki
# Processing Record 49 of Set 10| jiwani
# Processing Record 50 of Set 10| warrington
# Processing Record 1 of Set 11| ipueiras
# Processing Record 2 of Set 11| kropotkin
# City not found. Skipping ...
# Processing Record 3 of Set 11| labuhan
# Processing Record 4 of Set 11| batagay-alyta
# Processing Record 5 of Set 11| erdenet
# Processing Record 6 of Set 11| batagay
# Processing Record 7 of Set 11| talaya
# Processing Record 8 of Set 11| awbari
# Processing Record 9 of Set 11| sitamau
# Processing Record 10 of Set 11| dharchula
# Processing Record 11 of Set 11| gazojak
# Processing Record 12 of Set 11| ust-nera
# Processing Record 13 of Set 11| yumen
# Processing Record 14 of Set 11| bousso
# Processing Record 15 of Set 11| fortuna
# Processing Record 16 of Set 11| okato
# Processing Record 17 of Set 11| zeya
# Processing Record 18 of Set 11| kapit
# Processing Record 19 of Set 11| kamenka
# Processing Record 20 of Set 11| green river
# Processing Record 21 of Set 11| boddam
# City not found. Skipping ...
# Processing Record 22 of Set 11| candoni
# Processing Record 23 of Set 11| corn island
# Processing Record 24 of Set 11| margate
# Processing Record 25 of Set 11| husavik
# Processing Record 26 of Set 11| picui
# Processing Record 27 of Set 11| tarko-sale
# Processing Record 28 of Set 11| loreto
# Processing Record 29 of Set 11| lavrentiya
# Processing Record 30 of Set 11| turrialba
# Processing Record 31 of Set 11| pasni
# Processing Record 32 of Set 11| port blair
# Processing Record 33 of Set 11| zaraza
# Processing Record 34 of Set 11| vardo
# Processing Record 35 of Set 11| senneterre
# Processing Record 36 of Set 11| kolondieba
# Processing Record 37 of Set 11| hasaki
# Processing Record 38 of Set 11| cayenne
# Processing Record 39 of Set 11| ekibastuz
# Processing Record 40 of Set 11| kuytun
# Processing Record 41 of Set 11| akyab
# Processing Record 42 of Set 11| bonavista
# Processing Record 43 of Set 11| nabire
# Processing Record 44 of Set 11| haapiti
# Processing Record 45 of Set 11| saint anthony
# Processing Record 46 of Set 11| namibe
# Processing Record 47 of Set 11| kabare
# Processing Record 48 of Set 11| umm lajj
# Processing Record 49 of Set 11| tessalit
# Processing Record 50 of Set 11| coihaique
# Processing Record 1 of Set 12| andalan
# Processing Record 2 of Set 12| bouza
# Processing Record 3 of Set 12| kargasok
# Processing Record 4 of Set 12| matara
# Processing Record 5 of Set 12| acari
# Processing Record 6 of Set 12| ardesen
# Processing Record 7 of Set 12| koulikoro
# -----------------------------
#  Data Retreival Complete
# -----------------------------

# %%
### Convert Raw Data to DataFrame
weather_df=pd.DataFrame({"City": city_list, "Cloudiness":cloudiness, "Country":country, "Date":date,
                        "Humidity":humidity, "Lat":lat, "Lng":lng, "Max Temp":max_temp,
                        "Wind Speed": wind_speed, })
weather_df.to_csv("cities.csv")
weather_df.count()
# Out:
# City          557
# Cloudiness    557
# Country       557
# Date          557
# Humidity      557
# Lat           557
# Lng           557
# Max Temp      557
# Wind Speed    557
# dtype: int64

# %%
weather_df.head()
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0            Hilo          90      US  1604374005        78  19.73 -155.09
# 1  Port Elizabeth           0      ZA  1604373709        93 -33.92   25.57
# 2  Ribeira Grande          80      PT  1604374005        65  38.52  -28.70
# 3         Aklavik         100      CA  1604373717        84  68.22 -135.01
# 4      Porto-Novo          20      BJ  1604374005        88   6.50    2.60
#
#    Max Temp  Wind Speed
# 0     80.60        6.15
# 1     64.40       14.99
# 2     62.28       15.08
# 3     -0.40        3.36
# 4     78.80        1.12

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
from datetime import date
today = date.today()
d1 = today.strftime("%d/%m/%Y")

# %%
plt.scatter(weather_df['Lat'], weather_df['Max Temp'], edgecolor="black")
plt.title(f"City Latitude vs. Max Temperature ({d1})")
plt.xlabel("Latitude")
plt.ylabel("Max Tempreture (F)")
plt.grid()
plt.savefig("Latitude vs Temperature.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df['Lat'], weather_df['Humidity'], edgecolor="black")
plt.title(f"City Latitude vs. Humidity ({d1})")
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.grid()
plt.savefig("Latitude vs Humidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df['Lat'], weather_df['Cloudiness'], edgecolor="black")
plt.title(f"City Latitude vs. Cloudiness ({d1})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.grid()
plt.savefig("Latitude vs Cloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df['Lat'], weather_df['Wind Speed'], edgecolor="black")
plt.title(f"City Latitude vs. Speed ({d1})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.savefig("Latitude vs Wind Speed.png")
plt.show()

# %%
northern_hemisphere = weather_df.loc[(weather_df["Lat"]>=0)]
southern_hemisphere = weather_df.loc[(weather_df["Lat"]<0)]

# %%
# Linear regression for Northern Hemisphere Temperature (F) vs. Latitude:
# setting values for x and y:
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Max Temp']

# Perform a linear regression on Northern Hemisphere Temperature (F) vs. Latitude:
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Northern Hemisphere Temperature (F)')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")
plt.title("Northern Hemisphere Temperature (F) vs. Latitude")

# Print r value
print(f"The r-value is: {rvalue**2}")
plt.savefig("images/Northern Hemisphere Temperature (F) vs Latitude.png")
# Show plot
plt.show()
# Out:
# The r-value is: 0.7342042418206293

# %%
# Linear regression for Southern Hemisphere Temperature (F) vs. Latitude:
# setting values for x and y:
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Max Temp']

# Perform a linear Southern Hemisphere Temperature (F) vs. Latitude:
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Southern Hemisphere Temperature (F)')
plt.annotate(line_eq,(-30,60),fontsize=15,color="red")
plt.title("Southern Hemisphere Temperature (F) vs. Latitude")

# Print r value
print(f"The r-value is: {rvalue**2}")
plt.savefig("images/Southern Hemisphere Temperature (F) vs Latitude.png")
# Show plot
plt.show()
# Out:
# The r-value is: 0.42693123198357674

# %%
# Linear regression for Northern Hemisphere Humidity (%) vs. Latitude:
# setting values for x and y:
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Humidity']

# Perform a linear regression on Northern Hemisphere Humidity (%) vs. Latitude:
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Northern Hemisphere Humidity (%)')
plt.annotate(line_eq,(30,60),fontsize=15,color="red")
plt.title("Northern Hemisphere Humidity (%) vs. Latitude")

# Print r value
print(f"The r-value is: {rvalue**2}")
plt.savefig("images/Northern Hemisphere Humidity (%) vs Latitude.png")
# Show plot
plt.show()
# Out:
# The r-value is: 0.09959656010948431

# %%
# Linear regression for Southern Hemisphere Humidity (%) vs. Latitude:
# setting values for x and y:
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Humidity']

# Perform a linear Southern Hemisphere Humidity (%) vs. Latitude:
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Southern Hemisphere Humidity (%)')
plt.annotate(line_eq,(-30,60),fontsize=15,color="red")
plt.title("Southern Hemisphere Humidity (%) vs. Latitude")

# Print r value
print(f"The r-value is: {rvalue**2}")
plt.savefig("images/Southern Hemisphere Humidity (%) vs Latitude.png")
# Show plot
plt.show()
# Out:
# The r-value is: 0.002137604190925985

# %%
# Linear regression for Northern Hemisphere Cloudiness (%) vs. Latitude:
# setting values for x and y:
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Cloudiness']

# Perform a linear regression on Northern Hemisphere Cloudiness (%) vs. Latitude:
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Northern Hemisphere Cloudiness (%)')
plt.annotate(line_eq,(30,60),fontsize=15,color="red")
plt.title("Northern Hemisphere Cloudiness (%) vs. Latitude")

# Print r value
print(f"The r-value is: {rvalue**2}")
plt.savefig("images/Northern Hemisphere Cloudiness (%) vs Latitude.png")
# Show plot
plt.show()
# Out:
# The r-value is: 0.02120693190703407

# %%
# Linear regression for Southern Hemisphere Cloudiness (%) vs. Latitude:
# setting values for x and y:
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Cloudiness']

# Perform a linear Southern Hemisphere Cloudiness (%) vs. Latitude:
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Southern Hemisphere Cloudiness (%)')
plt.annotate(line_eq,(-30,60),fontsize=15,color="red")
plt.title("Southern Hemisphere Cloudiness (%) vs. Latitude")

# Print r value
print(f"The r-value is: {rvalue**2}")
plt.savefig("images/Southern Hemisphere Cloudiness (%) vs Latitude.png")
# Show plot
plt.show()
# Out:
# The r-value is: 0.040262937004635194

# %%
# Linear regression for Northern Hemisphere Wind Speed (mph) vs. Latitude:
# setting values for x and y:
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Wind Speed']

# Perform a linear regression on Northern Hemisphere Wind Speed (mph) vs. Latitude:
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Northern Hemisphere Wind Speed (mph)')
plt.annotate(line_eq,(40,10),fontsize=15,color="red")
plt.title("Northern Hemisphere Wind Speed (mph) vs. Latitude")

# Print r value
print(f"The r-value is: {rvalue**2}")
plt.savefig("images/Northern Hemisphere Wind Speed (mph) vs Latitude.png")
# Show plot
plt.show()
# Out:
# The r-value is: 0.023398813873258522

# %%
# Linear regression for Southern Hemisphere Wind Speed (mph) vs. Latitude:
# setting values for x and y:
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Wind Speed']

# Perform a linear Southern Hemisphere Wind Speed (mph) vs. Latitude:
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Southern Hemisphere Wind Speed (mph)')
plt.annotate(line_eq,(-30,11),fontsize=15,color="red")
plt.title("Southern Hemisphere Wind Speed (mph) vs. Latitude")

# Print r value
print(f"The r-value is: {rvalue**2}")
plt.savefig("images/Southern Hemisphere Wind Speed (mph) vs Latitude.png")
# Show plot
plt.show()
# Out:
# The r-value is: 0.041968726507821054
